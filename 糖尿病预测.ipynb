# %% [markdown]
# <a href="https://colab.research.google.com/github/mw1314520/Algorithm_Interview_Notes-Chinese/blob/master/%E7%B3%96%E5%B0%BF%E7%97%85%E9%A2%84%E6%B5%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5289e141-99a5-42e6-8d06-1fb4ba36bcd9" name="files[]" multiple disabled />
#      <output id="result-5289e141-99a5-42e6-8d06-1fb4ba36bcd9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pima-indians-diabetes-database.zip to pima-indians-diabetes-database.zip
# ...

# %%
# !unzip pima-indians-diabetes-database.zip
# Out:
# Archive:  pima-indians-diabetes-database.zip
#   inflating: diabetes.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('diabetes.csv')

# %%
print("dataset shape {}".format(data.shape))
data.head()
# Out:
# dataset shape (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.groupby("Outcome").size()
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
X=data.iloc[:,0:8]
Y=data.iloc[:,8]
print('Shape of X:{0};shape of Y:{1}'.format(X.shape,Y.shape))
# Out:
# Shape of X:(768, 8);shape of Y:(768,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.8)

# %%
from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier
models=[]
models.append(["KNN",KNeighborsClassifier(n_neighbors=5)])
models.append(["KNN with weights",KNeighborsClassifier(n_neighbors=5,weights='distance')])
models.append(["Radius Neighbors",RadiusNeighborsClassifier(n_neighbors=5,radius=500.0)])

results=[]
for name,model in models:
  model.fit(X_train,Y_train)
  results.append([name,model.score(X_test,Y_test)])
for i in range(len(results)):
  print("name:{0}----score:{1}\n".format(results[i][0],results[i][1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d5ef17410cc5> in <module>()
#       7 results=[]
#       8 for name,model in models:
# ----> 9   model.fit(X_train,Y_train)
#      10   results.append([name,model.score(X_test,Y_test)])
#      11 for i in range(len(results)):
#
# NameError: name 'X_train' is not defined
